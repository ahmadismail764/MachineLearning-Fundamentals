# %% [markdown]
# # Lab 2 Practice Exercise: Data Preprocessing
#
# This notebook is designed to help you practice the concepts of data exploration, cleaning, and visualization using the `money_default.csv` dataset.
#
# **Instructions:**
# - Follow the markdown instructions for each section.
# - Write your code in the empty code cells provided.
# - Refer to the original `Lab_2_Introduction_to_Data_Preprocessing.ipynb` for guidance on specific methods and functions.

# %% [markdown]
# ### 1. Environment Setup
#
# Import the necessary libraries: `pandas` for data manipulation, `seaborn` for visualization, and `matplotlib.pyplot` for plot customization.

# %% [markdown]
# ### 2. Data Acquisition
#
# Load the dataset located at `data/money_default.csv` into a pandas DataFrame named `df`. Display the first 5 rows to confirm it loaded correctly.

# %% [markdown]
# ### 3. Initial Data Inspection
#
# Use the appropriate methods to:
# 1. Check the dimensions of the dataset (`rows`, `columns`).
# 2. List all column names.
# 3. Display a concise summary of the DataFrame (including data types and non-null counts).

# %% [markdown]
# ### 4. Quantitative Analysis
#
# Generate descriptive statistics for all numerical features.
#
# *Question to consider:* Do any columns show signs of outliers (e.g., a very high `max` compared to the `mean` or `75%` percentile)?

# %% [markdown]
# ### 5. Data Cleaning - Dropping Columns
#
# The `ID` column is an identifier and doesn't provide predictive value for analysis. Drop the `ID` column from the DataFrame (you can do this `inplace`).

# %% [markdown]
# ### 6. Qualitative Analysis
#
# Even though some columns like `SEX`, `EDUCATION`, and `MARRIAGE` are numerical, they actually represent categories. Use `.value_counts()` to see the distribution of values for these columns.
#
# *Bonus:* Use `normalize=True` to see the proportions instead of raw counts.

# %% [markdown]
# ### 7. Data Integrity - Duplicates
#
# Check if there are any duplicate rows in the dataset. If there are, remove them and reset the index.

# %% [markdown]
# ### 8. Data Completeness - Missing Values
#
# Identify the number of missing (null) values for each column in the dataset.

# %%
# Out:
#   Cell In[1], line 3
#     Identify the number of missing (null) values for each column in the dataset.
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 9. Visual Exploratory Data Analysis (EDA)
#
# Visualizations help reveal patterns that numbers might hide.
#
# 1. Create a **pair plot** for a subset of numerical columns (e.g., `LIMIT_BAL`, `AGE`, `BILL_AMT1`).
# 2. Create a **count plot** for the target variable `default_payment_next_month` to see how balanced the classes are.

# %% [markdown]
# ### 10. Relationship Analysis
#
# Compute the correlation matrix for all features and visualize it using a **heatmap**. Use `annot=True` to display the correlation values.
